# %%
import openpyxl as oxl
import pandas as pd
import numpy as np
import geopandas as gpd

from thefuzz import fuzz
from thefuzz import process as fzproc

import pathlib as plb

# %%
WORK_DIR = plb.Path().resolve().parent
INPUT_DIR = WORK_DIR / "data_inputs"
OUTPUT_DIR = WORK_DIR / "data_outputs"
NOTEBOOK_DIR = WORK_DIR / "notebooks"
SCRIPTS_DIR = WORK_DIR / "scripts"
PSGC_DIR = WORK_DIR.parent.parent / "E- Administrative Boundaries"
BOUNDS_DIR = WORK_DIR.parent.parent / "E- Administrative Boundaries" / "phl_adm_psa_namria_20231106_shp"

# %%
import sys
sys.path.append(str(WORK_DIR))

from scripts import parse_cph_excel as pcxl

# %%
fp_cph_2b = INPUT_DIR / "2020 Report 2B_Attachment_Housing.xlsx"
assert fp_cph_2b.exists()

# %%
fp_psgc = PSGC_DIR / "PSGC-1Q-2023-Publication-Datafile.xlsx"
assert fp_psgc.exists()

# %%
fp_ab3 = BOUNDS_DIR / "phl_admbnda_adm3_psa_namria_20231106.shp"
assert fp_ab3.exists()

# %%
target_sheet = "T7"

kwargs = {
    "start_row": 12,
    "n_footers": 5,
}

# %%
workbook = oxl.load_workbook(fp_cph_2b)
sheet = workbook[target_sheet]

# %%
sheet_full = pcxl.remove_blank_rows(sheet, **kwargs)

# %%
col_names = pd.read_excel(
    fp_psgc,
    sheet_name="PSGC",
    nrows=2
).columns.values.tolist()

col_names
# Out:
# ['10-digit PSGC',
#  'Name',
#  'Correspondence Code',
#  'Geographic Level',
#  'Old names',
#  'City Class',
#  'Income\nClassification',
#  'Urban / Rural\n(based on 2020 CPH)',
#  '2015 Population',
#  'Unnamed: 9',
#  '2020 Population',
#  'Unnamed: 11',
#  'Status']

# %%
df_psgc = pd.read_excel(
    fp_psgc,
    sheet_name="PSGC",
    nrows=43789,
    dtype={col: str for col in col_names[:-5]}
)

df_psgc.head()
# Out:
#   10-digit PSGC                      Name Correspondence Code  \
# 0    0100000000  Region I (Ilocos Region)           010000000
# 1    0102800000              Ilocos Norte           012800000
# 2    0102801000                     Adams           012801000
# 3    0102801001                     Adams           012801001
# 4    0102802000                   Bacarra           012802000
#
#   Geographic Level Old names City Class Income\nClassification  \
# 0              Reg       NaN        NaN                    NaN
# 1             Prov       NaN        NaN                    1st
# 2              Mun       NaN        NaN                    5th
# 3              Bgy       NaN        NaN                    NaN
# 4              Mun       NaN        NaN                    3rd
#
#   Urban / Rural\n(based on 2020 CPH) 2015 Population Unnamed: 9  \
# 0                                NaN         5026128        NaN
# 1                                NaN          593081        NaN
# ...

# %%
cities = pcxl.get_column_from_sheet(sheet_full, 1, substr="CITY", **kwargs)
cities
# Out:
# ['CITY OF MANILA',
#  'CITY OF MANDALUYONG',
#  'CITY OF MARIKINA',
#  'CITY OF PASIG',
#  'QUEZON CITY',
#  'CITY OF SAN JUAN',
#  'CITY OF CALOOCAN',
#  'CITY OF MALABON',
#  'CITY OF NAVOTAS',
#  'CITY OF VALENZUELA',
#  'CITY OF LAS PIÑAS',
#  'CITY OF MAKATI',
#  'CITY OF MUNTINLUPA',
#  'CITY OF PARAÑAQUE',
#  'PASAY CITY',
#  'CITY OF TAGUIG',
#  'CITY OF BAGUIO',
#  'CITY OF TABUK (Capital)',
#  'CITY OF BATAC',
#  'CITY OF LAOAG (Capital)',
#  'CITY OF CANDON',
#  'CITY OF VIGAN (Capital)',
#  'CITY OF SAN FERNANDO (Capital)',
#  'CITY OF ALAMINOS',
#  'CITY OF DAGUPAN',
#  'CITY OF SAN CARLOS',
#  'CITY OF URDANETA',
#  'TUGUEGARAO CITY (Capital)',
#  'CITY OF CAUAYAN',
#  'CITY OF ILAGAN (Capital)',
#  'CITY OF SANTIAGO',
#  'CITY OF BALANGA (Capital)',
#  'CITY OF MALOLOS (Capital)',
#  'CITY OF MEYCAUAYAN',
#  'CITY OF SAN JOSE DEL MONTE',
#  'CITY OF CABANATUAN',
#  'CITY OF GAPAN',
#  'SCIENCE CITY OF MUÑOZ',
#  'CITY OF PALAYAN (Capital)',
#  'SAN JOSE CITY',
# ...

# %%
hucs = pcxl.get_huc_names(df_psgc, choices=cities)
hucs
# Out:
# 7538                        CITY OF ANGELES
# 8745                       CITY OF OLONGAPO
# 12365              CITY OF LUCENA (Capital)
# 14323     CITY OF PUERTO PRINCESA (Capital)
# 20500              CITY OF ILOILO (Capital)
# 21741             CITY OF BACOLOD (Capital)
# 24067                CITY OF CEBU (Capital)
# 24353              CITY OF LAPU-LAPU (OPON)
# 24429                       CITY OF MANDAUE
# 27706            CITY OF TACLOBAN (Capital)
# 31506                     CITY OF ZAMBOANGA
# 32791                        CITY OF ILIGAN
# 33833      CITY OF CAGAYAN DE ORO (Capital)
# 34559                         CITY OF DAVAO
# 36037    CITY OF GENERAL SANTOS (DADIANGAS)
# 36665                        CITY OF MANILA
# 37578                   CITY OF MANDALUYONG
# 37606                      CITY OF MARIKINA
# 37623                         CITY OF PASIG
# 37654                           QUEZON CITY
# 37797                      CITY OF SAN JUAN
# ...

# %%
sheet_hucs = pcxl.change_indent_based_on_series(sheet_full, hucs, delta_indent=1, **kwargs)

# %%
sheet_final = pcxl.change_indent_based_on_series(sheet_hucs, pd.Series(["SOUTHERN LEYTE"]), delta_indent=-1, **kwargs)

# %%
sheet_final = pcxl.change_indent_based_on_series(sheet_final, pd.Series(["EASTERN SAMAR"]), delta_indent=1, **kwargs)

# %%
sheet_classified = pcxl.insert_indent_status_column(sheet_final, **kwargs)

# %%
toilet_facility_col_names = [
    "flush_sewer",
    "flush_septic",
    "flush_latrine",
    "flush_open_drain",
    "flush_unknown",
    "improved_latrine",
    "pit_latrine_slab",
    "pit_latrine_open",
    "composting_toilet",
    "bucket_pail",
    "hanging_toilet_latrine",
    "no_facility",
    "others"
]

# %%
sanitation_data = list(sheet_classified.values)[11:1753]
sanitation_data = [list(row)[:16] for row in sanitation_data]

# %%
for row in sanitation_data:
    print(row)
# Out:
# ['R', 'PHILIPPINES', 26374653, 3671036, 17353259, 2441524, 353364, 145031, 332553, 292379, 125357, 104032, 172644, 211823, 874021, 297631]
# ['R', 'NATIONAL CAPITAL REGION (NCR)', 3494249, 1119922, 2081331, 39811, 37090, 14834, 7003, 4439, 2210, 3063, 41840, 4660, 4885, 133160]
# ['M', 'CITY OF MANILA', 483261, 160135, 278515, 8764, 5603, 4783, 731, 1139, 454, 211, 7432, 1309, 1683, 12501]
# ['M', 'CITY OF MANDALUYONG', 116505, 34278, 72397, 1022, 937, 206, 121, 52, 5, 0, 1124, 42, 47, 6274]
# ['M', 'CITY OF MARIKINA', 104404, 40928, 59274, 915, 718, 182, 24, 73, 86, 67, 1114, 39, 81, 903]
# ['M', 'CITY OF PASIG', 212864, 79974, 117516, 1274, 1574, 1071, 405, 273, 16, 418, 4496, 161, 146, 5538]
# ['M', 'QUEZON CITY', 738330, 250313, 435094, 8870, 9191, 2116, 3770, 922, 45, 538, 10733, 504, 567, 15667]
# ['M', 'CITY OF SAN JUAN', 31400, 12018, 15177, 181, 831, 74, 34, 24, 10, 0, 64, 15, 24, 2948]
# ...

# %%
sanitation_col_names = toilet_facility_col_names.copy()
for col in ["n_households", "geolocation", "loc_marker"]:
    sanitation_col_names.insert(0, col)

df_sanitation = pd.DataFrame(
    sanitation_data,
    columns=sanitation_col_names
)

is_philippines = df_sanitation["geolocation"] == "PHILIPPINES"
df_sanitation = df_sanitation[~is_philippines]

df_sanitation.head()
# Out:
#   loc_marker                    geolocation  n_households  flush_sewer  \
# 1          R  NATIONAL CAPITAL REGION (NCR)       3494249      1119922
# 2          M                 CITY OF MANILA        483261       160135
# 3          M            CITY OF MANDALUYONG        116505        34278
# 4          M               CITY OF MARIKINA        104404        40928
# 5          M                  CITY OF PASIG        212864        79974
#
#    flush_septic  flush_latrine  flush_open_drain  flush_unknown  \
# 1       2081331          39811             37090          14834
# 2        278515           8764              5603           4783
# 3         72397           1022               937            206
# 4         59274            915               718            182
# 5        117516           1274              1574           1071
#
#    improved_latrine  pit_latrine_slab  pit_latrine_open  composting_toilet  \
# ...

# %%
df_sanitation.tail()
# Out:
#      loc_marker          geolocation  n_households  flush_sewer  flush_septic  \
# 1737          M  MIDSAYAP CLUSTER II          4274          348          1628
# 1738          M   PIGKAWAYAN CLUSTER          4356          106          2114
# 1739          M      PIKIT CLUSTER I          8935           40          4270
# 1740          M     PIKIT CLUSTER II          7978          111          1849
# 1741          M    PIKIT CLUSTER III          6566          207          2576
#
#       flush_latrine  flush_open_drain  flush_unknown  improved_latrine  \
# 1737            289               486            128                25
# 1738            290                41             78               122
# 1739           1979               686             77               198
# 1740           1936               578            431               271
# 1741           1038               597             79               674
#
# ...

# %%
is_region = df_sanitation["loc_marker"] == "R"
df_sanitation.loc[is_region, "region"] = df_sanitation.loc[is_region, "geolocation"]

df_sanitation["region"] = df_sanitation["region"].ffill()
df_sanitation = df_sanitation[~is_region]

df_sanitation.head()
# Out:
#   loc_marker          geolocation  n_households  flush_sewer  flush_septic  \
# 2          M       CITY OF MANILA        483261       160135        278515
# 3          M  CITY OF MANDALUYONG        116505        34278         72397
# 4          M     CITY OF MARIKINA        104404        40928         59274
# 5          M        CITY OF PASIG        212864        79974        117516
# 6          M          QUEZON CITY        738330       250313        435094
#
#    flush_latrine  flush_open_drain  flush_unknown  improved_latrine  \
# 2           8764              5603           4783               731
# 3           1022               937            206               121
# 4            915               718            182                24
# 5           1274              1574           1071               405
# 6           8870              9191           2116              3770
#
#    pit_latrine_slab  pit_latrine_open  composting_toilet  bucket_pail  \
# ...

# %%
is_province = df_sanitation["loc_marker"] == "P"
df_sanitation.loc[is_province, "province"] = df_sanitation.loc[is_province, "geolocation"]

df_sanitation["province"] = df_sanitation["province"].ffill()
df_sanitation = df_sanitation[~is_province]

df_sanitation.head()
# Out:
#   loc_marker          geolocation  n_households  flush_sewer  flush_septic  \
# 2          M       CITY OF MANILA        483261       160135        278515
# 3          M  CITY OF MANDALUYONG        116505        34278         72397
# 4          M     CITY OF MARIKINA        104404        40928         59274
# 5          M        CITY OF PASIG        212864        79974        117516
# 6          M          QUEZON CITY        738330       250313        435094
#
#    flush_latrine  flush_open_drain  flush_unknown  improved_latrine  \
# 2           8764              5603           4783               731
# 3           1022               937            206               121
# 4            915               718            182                24
# 5           1274              1574           1071               405
# 6           8870              9191           2116              3770
#
#    pit_latrine_slab  pit_latrine_open  composting_toilet  bucket_pail  \
# ...

# %%
ncr_districts = {
    "METROPOLITAN MANILA FIRST DISTRICT": ["CITY OF MANILA"],
    "METROPOLITAN MANILA SECOND DISTRICT": [
        "CITY OF MANDALUYONG",
        "CITY OF MARIKINA",
        "CITY OF PASIG",
        "QUEZON CITY",
        "CITY OF SAN JUAN"
    ],
    "METROPOLITAN MANILA THIRD DISTRICT": [
        "CITY OF CALOOCAN",
        "CITY OF MALABON",
        "CITY OF NAVOTAS",
        "CITY OF VALENZUELA"
    ],
    "METROPOLITAN MANILA FOURTH DISTRICT": [
        "CITY OF LAS PIÑAS",
        "CITY OF MAKATI",
        "CITY OF MUNTINLUPA",
        "CITY OF PARAÑAQUE",
        "PASAY CITY",
        "PATEROS",
        "CITY OF TAGUIG"
    ]
}

# for district in ncr_districts:
#     print([city for city in ncr_districts[district]])

for district in ncr_districts:
    is_in_district = df_sanitation["geolocation"].isin(ncr_districts[district])
    df_sanitation.loc[is_in_district, "province"] = district

df_sanitation.head()
# Out:
#   loc_marker          geolocation  n_households  flush_sewer  flush_septic  \
# 2          M       CITY OF MANILA        483261       160135        278515
# 3          M  CITY OF MANDALUYONG        116505        34278         72397
# 4          M     CITY OF MARIKINA        104404        40928         59274
# 5          M        CITY OF PASIG        212864        79974        117516
# 6          M          QUEZON CITY        738330       250313        435094
#
#    flush_latrine  flush_open_drain  flush_unknown  improved_latrine  \
# 2           8764              5603           4783               731
# 3           1022               937            206               121
# 4            915               718            182                24
# 5           1274              1574           1071               405
# 6           8870              9191           2116              3770
#
#    pit_latrine_slab  pit_latrine_open  composting_toilet  bucket_pail  \
# ...

# %%
df_sanitation = df_sanitation.drop(columns=["loc_marker"]) \
                    .rename(columns={"geolocation": "municipality"})

geolocation_levels = ["region", "province", "municipality"]

df_sanitation = df_sanitation[geolocation_levels + ["n_households"] + toilet_facility_col_names]

df_sanitation.head()
# Out:
#                           region                             province  \
# 2  NATIONAL CAPITAL REGION (NCR)   METROPOLITAN MANILA FIRST DISTRICT
# 3  NATIONAL CAPITAL REGION (NCR)  METROPOLITAN MANILA SECOND DISTRICT
# 4  NATIONAL CAPITAL REGION (NCR)  METROPOLITAN MANILA SECOND DISTRICT
# 5  NATIONAL CAPITAL REGION (NCR)  METROPOLITAN MANILA SECOND DISTRICT
# 6  NATIONAL CAPITAL REGION (NCR)  METROPOLITAN MANILA SECOND DISTRICT
#
#           municipality  n_households  flush_sewer  flush_septic  \
# 2       CITY OF MANILA        483261       160135        278515
# 3  CITY OF MANDALUYONG        116505        34278         72397
# 4     CITY OF MARIKINA        104404        40928         59274
# 5        CITY OF PASIG        212864        79974        117516
# 6          QUEZON CITY        738330       250313        435094
#
#    flush_latrine  flush_open_drain  flush_unknown  improved_latrine  \
# 2           8764              5603           4783               731
# ...

# %%
is_interim = df_sanitation["province"] == "INTERIM PROVINCE 1"
df_sanitation.loc[is_interim, "province"] = "SPECIAL GEOGRAPHIC AREA"

df_sanitation.tail()
# Out:
#                                                  region  \
# 1737  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
# 1738  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
# 1739  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
# 1740  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
# 1741  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
#
#                      province         municipality  n_households  flush_sewer  \
# 1737  SPECIAL GEOGRAPHIC AREA  MIDSAYAP CLUSTER II          4274          348
# 1738  SPECIAL GEOGRAPHIC AREA   PIGKAWAYAN CLUSTER          4356          106
# 1739  SPECIAL GEOGRAPHIC AREA      PIKIT CLUSTER I          8935           40
# 1740  SPECIAL GEOGRAPHIC AREA     PIKIT CLUSTER II          7978          111
# 1741  SPECIAL GEOGRAPHIC AREA    PIKIT CLUSTER III          6566          207
#
#       flush_septic  flush_latrine  flush_open_drain  flush_unknown  \
# 1737          1628            289               486            128
# ...

# %%
is_city_isabela = df_sanitation["municipality"].str.contains("CITY OF ISABELA")
df_sanitation.loc[is_city_isabela, "province"] = "CITY OF ISABELA (NOT A PROVINCE)"

# %%
including_excluding = (df_sanitation["province"].str.contains(r"^.* \(including .*\)$", regex=True)) \
                    | (df_sanitation["province"].str.contains(r"^.* \(excluding .*\)$", regex=True))

df_sanitation.loc[including_excluding, "province"] = df_sanitation.loc[including_excluding, "province"].str.replace(r"^(.*) \(.*\)$", "\\1", regex=True)

df_sanitation[including_excluding].sample(5)
# Out:
#                                                  region     province  \
# 1614  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...      BASILAN
# 1687  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  MAGUINDANAO
# 1616  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...      BASILAN
# 1685  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  MAGUINDANAO
# 1696  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...  MAGUINDANAO
#
#         municipality  n_households  flush_sewer  flush_septic  flush_latrine  \
# 1614       TIPO-TIPO          4195           86          1207            533
# 1687  SULTAN MASTURA          4445          371          2030            833
# 1616           AKBAR          3621           26           947           1184
# 1685       PAGAGAWAN          6019           59          3046            688
# 1696          PANDAG          4146           57          1857            470
#
#       flush_open_drain  flush_unknown  improved_latrine  pit_latrine_slab  \
# ...

# %%
improved_toilet_facilities = [
    "flush_sewer",
    "flush_septic",
    "flush_latrine",
    "improved_latrine",
    "pit_latrine_slab",
    "composting_toilet"
]

open_defecation = ["no_facility"]

target_cols_in_improved_toilet = improved_toilet_facilities + geolocation_levels + open_defecation + ["n_households"]

df_improved_sanitation = df_sanitation.copy(deep=True) \
                        .drop(columns=[
                            col for col in df_sanitation.columns.values if col not in target_cols_in_improved_toilet
                        ])
df_improved_sanitation["pc_improved"] = round(df_improved_sanitation[improved_toilet_facilities].sum(axis=1) / df_improved_sanitation["n_households"], 5)
df_improved_sanitation["pc_open_defecation"] = round(df_improved_sanitation["no_facility"] / df_improved_sanitation["n_households"], 5)
df_improved_sanitation["pc_unimproved"] = 1.0 - (df_improved_sanitation["pc_improved"] + df_improved_sanitation["pc_open_defecation"])

df_improved_sanitation.sample(10)
# Out:
#                                                  region       province  \
# 731                             REGION V (BICOL REGION)  CAMARINES SUR
# 798                             REGION V (BICOL REGION)        MASBATE
# 480                            REGION IV-A (CALABARZON)       BATANGAS
# 385                          REGION III (CENTRAL LUZON)    NUEVA ECIJA
# 984                        REGION VII (CENTRAL VISAYAS)          BOHOL
# 1619  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...        BASILAN
# 111                            REGION I (ILOCOS REGION)   ILOCOS NORTE
# 319                          REGION II (CAGAYAN VALLEY)  NUEVA VIZCAYA
# 56               CORDILLERA ADMINISTRATIVE REGION (CAR)        BENGUET
# 305                          REGION II (CAGAYAN VALLEY)        ISABELA
#
#        municipality  n_households  flush_sewer  flush_septic  flush_latrine  \
# 731            BAAO         13199         1258          9710            939
# ...

# %%
df_improved_sanitation["address"] = df_improved_sanitation["province"] + ", " + df_improved_sanitation["municipality"]
df_improved_sanitation.sample(10)
# Out:
#                                                  region  \
# 742                             REGION V (BICOL REGION)
# 56               CORDILLERA ADMINISTRATIVE REGION (CAR)
# 191                            REGION I (ILOCOS REGION)
# 824                         REGION VI (WESTERN VISAYAS)
# 1212                      REGION VIII (EASTERN VISAYAS)
# 1557                               REGION XIII (Caraga)
# 433                          REGION III (CENTRAL LUZON)
# 265                          REGION II (CAGAYAN VALLEY)
# 311                          REGION II (CAGAYAN VALLEY)
# 1657  BANGSAMORO AUTONOMOUS REGION IN MUSLIM MINDANA...
#
#                    province    municipality  n_households  flush_sewer  \
# 742           CAMARINES SUR     DEL GALLEGO          6102          208
# 56                  BENGUET        KIBUNGAN          4126           10
# 191              PANGASINAN        BALUNGAO          7908          875
# ...

# %%
df_improved_sanitation.plot(
    kind="hist",
    y="pc_improved",
    histtype="step",
    bins=40
)
# Out:
# <Axes: ylabel='Frequency'>

# %%
gdf_ab3 = gpd.read_file(fp_ab3)
gdf_ab3.head()
# Out:
#          ADM3_EN ADM3_PCODE       ADM2_EN ADM2_PCODE  \
# 0          Adams  PH0102801  Ilocos Norte    PH01028
# 1        Bacarra  PH0102802  Ilocos Norte    PH01028
# 2          Badoc  PH0102803  Ilocos Norte    PH01028
# 3         Bangui  PH0102804  Ilocos Norte    PH01028
# 4  City of Batac  PH0102805  Ilocos Norte    PH01028
#
#                     ADM1_EN ADM1_PCODE            ADM0_EN ADM0_PCODE  \
# 0  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 1  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 2  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 3  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 4  Region I (Ilocos Region)       PH01  Philippines (the)         PH
#
#          date     validOn validTo ADM3_REF ADM3ALT1EN  Shape_Leng  Shape_Area  \
# 0  2022-11-09  2023-11-06    None     None       None    0.423604    0.009506
# ...

# %%
is_special_area = gdf_ab3["ADM2_EN"] == "Special Geographic Area"

gdf_ab3.loc[is_special_area, "ADM3_EN"] = gdf_ab3.loc[is_special_area, "ADM3_EN"].str.replace("Special Geographic Area - ", "")

# %%
is_maguindanao = gdf_ab3["ADM2_EN"].str.contains(r"^Maguindanao", regex=True)

gdf_ab3.loc[is_maguindanao, "ADM2_EN"] = gdf_ab3.loc[is_maguindanao, "ADM2_EN"].str.replace(r"^(Maguindanao).*", "Maguindanao", regex=True)
gdf_ab3[is_maguindanao].sample(10)
# Out:
#                                 ADM3_EN ADM3_PCODE      ADM2_EN ADM2_PCODE  \
# 1623                       Guindulungan  PH1908825  Maguindanao    PH19088
# 1613                         Datu Piang  PH1908806  Maguindanao    PH19088
# 1631               Datu Hoffer Ampatuan  PH1908835  Maguindanao    PH19088
# 1608               Datu Blah T. Sinsuat  PH1908730  Maguindanao    PH19087
# 1630                             Pandag  PH1908833  Maguindanao    PH19088
# 1612                        Datu Paglas  PH1908805  Maguindanao    PH19088
# 1614  Shariff Aguak (Maganoy) (Capital)  PH1908808  Maguindanao    PH19088
# 1601                             Parang  PH1908711  Maguindanao    PH19087
# 1622                             Paglat  PH1908823  Maguindanao    PH19088
# 1624                Datu Saudi-Ampatuan  PH1908826  Maguindanao    PH19088
#
#                                                 ADM1_EN ADM1_PCODE  \
# 1623  Bangsamoro Autonomous Region In Muslim Mindana...       PH19
# ...

# %%
gdf_ab3["ADDR"] = gdf_ab3["ADM2_EN"] + ", " + gdf_ab3["ADM3_EN"]
gdf_ab3.head()
# Out:
#          ADM3_EN ADM3_PCODE       ADM2_EN ADM2_PCODE  \
# 0          Adams  PH0102801  Ilocos Norte    PH01028
# 1        Bacarra  PH0102802  Ilocos Norte    PH01028
# 2          Badoc  PH0102803  Ilocos Norte    PH01028
# 3         Bangui  PH0102804  Ilocos Norte    PH01028
# 4  City of Batac  PH0102805  Ilocos Norte    PH01028
#
#                     ADM1_EN ADM1_PCODE            ADM0_EN ADM0_PCODE  \
# 0  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 1  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 2  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 3  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 4  Region I (Ilocos Region)       PH01  Philippines (the)         PH
#
#          date     validOn validTo ADM3_REF ADM3ALT1EN  Shape_Leng  Shape_Area  \
# 0  2022-11-09  2023-11-06    None     None       None    0.423604    0.009506
# ...

# %%
unique_addresses = df_improved_sanitation["address"].unique()

gdf_ab3["MATCH"] = gdf_ab3["ADDR"].apply(
    lambda x: fzproc.extractOne(
        x, 
        unique_addresses, 
        scorer=fuzz.WRatio, 
        score_cutoff=80
    )
)

gdf_ab3[gdf_ab3["MATCH"].isna()]
# Out:
# Empty GeoDataFrame
# Columns: [ADM3_EN, ADM3_PCODE, ADM2_EN, ADM2_PCODE, ADM1_EN, ADM1_PCODE, ADM0_EN, ADM0_PCODE, date, validOn, validTo, ADM3_REF, ADM3ALT1EN, Shape_Leng, Shape_Area, AREA_SQKM, geometry, ADDR, MATCH]
# Index: []

# %%
is_duplicated = gdf_ab3["MATCH"].str[0].duplicated(keep=False)

is_double_duplicated = gdf_ab3["MATCH"].duplicated(keep=False)

is_single_duplicated = is_duplicated & ~is_double_duplicated

# Case 1: is_duplicated & ~is_double_duplicated
duplicated_addresses = gdf_ab3.loc[is_single_duplicated, "MATCH"].str[0].unique()
duplicated_addresses

for address in duplicated_addresses:
    has_address = gdf_ab3["MATCH"].str[0] == address
    
    lower_score = gdf_ab3.loc[has_address, "MATCH"].str[1].astype(int).min()
    
    has_lower_score = gdf_ab3["MATCH"].str[1] == lower_score

    must_rematch = has_address & has_lower_score

    gdf_ab3.loc[must_rematch, "MATCH"] = gdf_ab3.loc[must_rematch, "ADDR"].apply(
        lambda x: fzproc.extractOne(
            x,
            unique_addresses,
            scorer=fuzz.partial_token_sort_ratio,
            score_cutoff=80
        )
    )

gdf_ab3[is_single_duplicated]
# Out:
#                       ADM3_EN ADM3_PCODE                             ADM2_EN  \
# 232           City of Baliwag  PH0301403                             Bulacan
# 354            City of Calaca  PH0401007                            Batangas
# 361                 Lipa City  PH0401014                            Batangas
# 1189               Davao City  PH1102402                       Davao del Sur
# 1190  City of Digos (Capital)  PH1102403                       Davao del Sur
# 1275           City of Manila  PH1303901  Metropolitan Manila First District
#
#      ADM2_PCODE                        ADM1_EN ADM1_PCODE            ADM0_EN  \
# 232     PH03014     Region III (Central Luzon)       PH03  Philippines (the)
# 354     PH04010       Region IV-A (Calabarzon)       PH04  Philippines (the)
# 361     PH04010       Region IV-A (Calabarzon)       PH04  Philippines (the)
# 1189    PH11024       Region XI (Davao Region)       PH11  Philippines (the)
# ...

# %%
fuzz.token_sort_ratio("Metropolitan Manila Fourth District, Pateros", "METROPOLITAN MANILA FOURTH DISTRICT, PATEROS")
# Out:
# 100

# %%
double_duplicated_addresses = gdf_ab3.loc[is_double_duplicated, "MATCH"].str[0].unique()

for address in double_duplicated_addresses:
    has_address = gdf_ab3["MATCH"].str[0] == address

    gdf_ab3.loc[has_address, "MATCH"] = gdf_ab3.loc[has_address, "ADDR"].apply(
        lambda x: fzproc.extractOne(
            x,
            unique_addresses,
            scorer=fuzz.partial_token_sort_ratio,
            score_cutoff=80
        )
    )

gdf_ab3[is_double_duplicated]
# Out:
#                       ADM3_EN ADM3_PCODE            ADM2_EN ADM2_PCODE  \
# 384               Bacoor City  PH0402103             Cavite    PH04021
# 386               Cavite City  PH0402105             Cavite    PH04021
# 1052  Pagadian City (Capital)  PH0907322  Zamboanga del Sur    PH09073
# 1059           Zamboanga City  PH0907332  Zamboanga del Sur    PH09073
#
#                               ADM1_EN ADM1_PCODE            ADM0_EN  \
# 384          Region IV-A (Calabarzon)       PH04  Philippines (the)
# 386          Region IV-A (Calabarzon)       PH04  Philippines (the)
# 1052  Region IX (Zamboanga Peninsula)       PH09  Philippines (the)
# 1059  Region IX (Zamboanga Peninsula)       PH09  Philippines (the)
#
#      ADM0_PCODE        date     validOn validTo ADM3_REF ADM3ALT1EN  \
# 384          PH  2022-11-09  2023-11-06    None     None       None
# 386          PH  2022-11-09  2023-11-06    None     None       None
# ...

# %%
gdf_ab3["MATCH"] = gdf_ab3["MATCH"].str[0]

# %%
gdf_final = gdf_ab3.merge(
    df_improved_sanitation,
    how="left",
    left_on="MATCH",
    right_on="address",
    suffixes=["_gdf", "_df"],
    validate="one_to_one"
)

gdf_final.head()
# Out:
#          ADM3_EN ADM3_PCODE       ADM2_EN ADM2_PCODE  \
# 0          Adams  PH0102801  Ilocos Norte    PH01028
# 1        Bacarra  PH0102802  Ilocos Norte    PH01028
# 2          Badoc  PH0102803  Ilocos Norte    PH01028
# 3         Bangui  PH0102804  Ilocos Norte    PH01028
# 4  City of Batac  PH0102805  Ilocos Norte    PH01028
#
#                     ADM1_EN ADM1_PCODE            ADM0_EN ADM0_PCODE  \
# 0  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 1  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 2  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 3  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 4  Region I (Ilocos Region)       PH01  Philippines (the)         PH
#
#          date     validOn  ... flush_septic flush_latrine improved_latrine  \
# 0  2022-11-09  2023-11-06  ...          467             3                0
# 1  2022-11-09  2023-11-06  ...         7045           354              441
# ...

# %%
gdf_final = gdf_final.drop(columns=[
    "ADDR",
    "MATCH",
    "address"
] + geolocation_levels
).to_crs("EPSG:32651")

gdf_final.head()
# Out:
#          ADM3_EN ADM3_PCODE       ADM2_EN ADM2_PCODE  \
# 0          Adams  PH0102801  Ilocos Norte    PH01028
# 1        Bacarra  PH0102802  Ilocos Norte    PH01028
# 2          Badoc  PH0102803  Ilocos Norte    PH01028
# 3         Bangui  PH0102804  Ilocos Norte    PH01028
# 4  City of Batac  PH0102805  Ilocos Norte    PH01028
#
#                     ADM1_EN ADM1_PCODE            ADM0_EN ADM0_PCODE  \
# 0  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 1  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 2  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 3  Region I (Ilocos Region)       PH01  Philippines (the)         PH
# 4  Region I (Ilocos Region)       PH01  Philippines (the)         PH
#
#          date     validOn  ... flush_sewer flush_septic flush_latrine  \
# 0  2022-11-09  2023-11-06  ...          41          467             3
# 1  2022-11-09  2023-11-06  ...         634         7045           354
# ...

# %%
fp_output = OUTPUT_DIR / "PH_SanitationAccess_PSA-CPH_2020.shp"

gdf_final.to_file(fp_output)
# Out:
# C:\Users\HOWARD\AppData\Local\Temp\ipykernel_9668\712836748.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_final.to_file(fp_output)
